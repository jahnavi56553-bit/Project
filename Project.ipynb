# %%
import pandas as pd
df = pd.read_csv('employee_salary_prediction_dataset.csv')
print(df.head())
# Out:
#    Employee_Id  Age  Experience_Years Education_Level  Job_Level Department  \
# 0            1   30                 6        Bachelor          2         HR
# 1            2   40                19        Bachelor          5  Marketing
# 2            3   39                14             PhD          4    Finance
# 3            4   38                10          Master          4         IT
# 4            5   34                 7        Bachelor          3         IT
#
#    Performance_Score  Weekly_Working_Hours  Salary_LPA
# 0                  3                  43.1       18.71
# 1                  8                  40.8       42.69
# 2                  2                  44.8       39.37
# 3                  4                  37.1       33.53
# 4                  3                  48.5       25.56

# %%
df.columns
# Out:
# Index(['Employee_Id', 'Age', 'Experience_Years', 'Education_Level',
#        'Job_Level', 'Department', 'Performance_Score', 'Weekly_Working_Hours',
#        'Salary_LPA'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Employee_Id               int64
# Age                       int64
# Experience_Years          int64
# Education_Level             str
# Job_Level                 int64
# Department                  str
# Performance_Score         int64
# Weekly_Working_Hours    float64
# Salary_LPA              float64
# dtype: object

# %%
df.rename(columns={
    'Experience_Years':'Experience'
},inplace=True)

# %%
df.columns
# Out:
# Index(['Employee_Id', 'Age', 'Experience', 'Education_Level', 'Job_Level',
#        'Department', 'Performance_Score', 'Weekly_Working_Hours',
#        'Salary_LPA'],
#       dtype='str')

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1494    False
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# Length: 1499, dtype: bool

# %%
df.isnull().sum()
# Out:
# Employee_Id             0
# Age                     0
# Experience              0
# Education_Level         0
# Job_Level               0
# Department              0
# Performance_Score       0
# Weekly_Working_Hours    0
# Salary_LPA              0
# dtype: int64

# %%
import  matplotlib.pyplot as plt
import seaborn as sns
corr_matrix=df.corr(numeric_only=True)
plt.figure(figsize=(8,6))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="Blues",
    fmt=".2f",
    linewidths=0.5
)
plt.title("correlation matrix heatmap")
plt.show()

# %%
df.sort_values(by='Salary_LPA',ascending=False).head(10)
# Out:
#       Employee_Id  Age  Experience Education_Level  Job_Level Department  \
# 1158         1159   47          20             PhD          6         IT
# 917           918   45          20          Master          6         IT
# 743           744   42          18             PhD          6         IT
# 72             73   45          20             PhD          6         IT
# 675           676   41          16             PhD          6    Finance
# 1094         1095   37          18             PhD          6         IT
# 1126         1127   40          19             PhD          5         IT
# 639           640   43          16             PhD          6         IT
# 1358         1359   37          17             PhD          6         IT
# 405           406   44          19             PhD          5         IT
#
#       Performance_Score  Weekly_Working_Hours  Salary_LPA
# 1158                  7                  40.7       55.18
# 917                   9                  34.1       54.79
# 743                   8                  43.1       54.33
# 72                    6                  39.7       54.00
# 675                  10                  42.1       53.81
# 1094                  8                  44.3       53.73
# 1126                  9                  45.0       53.71
# 639                  10                  48.2       53.71
# 1358                  8                  41.6       53.48
# 405                  10                  37.0       53.26

# %%
q1 = df["Salary_LPA"].quantile(0.25)
q3 = df["Salary_LPA"].quantile(0.75)

IQR = q3 - q1

lower_limit = q1 - 1.5 * IQR
upper_limit = q3 + 1.5 * IQR

print("q1:", q1)
print("q3:", q3)
print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
outliers = df[
    (df["Salary_LPA"] < lower_limit) |
    (df["Salary_LPA"] > upper_limit)
]

print("\nSalary_LPA Outliers:",len(outliers))
print("\nSalary_LPA Outliers Data:\n")
print(outliers[[ "Employee_Id", "Salary_LPA"]].head(20))
# Out:
# Q1: 21.055
# Q3: 39.105000000000004
# Lower Limit: -6.020000000000007
# Upper Limit: 66.18
#
# Salary_LPA Outliers: 0
#
# Salary_LPA Outliers Data:
#
# Empty DataFrame
# Columns: [Employee_Id, Salary_LPA]
# Index: []

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.boxplot(df['Salary_LPA'])
plt.title("Salary_LPA outlier treatment")
plt.ylabel("Salary_LPA")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
gender=df.groupby("Department")["Salary_LPA"].mean()
plt.bar(gender.index,
        gender.values,
        color=["red","yellow","green"]
        )
plt.title("Department Avg Salary")
plt.xlabel("Department")
plt.ylabel("Salary_LPA")
plt.show()

# %%
Experience_vs_Salary = df.groupby("Experience")["Salary_LPA"].mean()
print("\nAverage Salary by Experience:")
print(Experience_vs_Salary)
plt.figure(figsize=(10,5))
plt.plot(
    Experience_vs_Salary.index,
    Experience_vs_Salary.values,
    marker="."
)

plt.title = ("Average Salary by Experience ")
plt.xlabel = ("Experience")
plt.ylabel = ("Salary_LPA")
plt.grid(True)
plt.show()
# Out:
# Average Salary by Experience:
# Experience
# 0     15.483571
# 1     15.891053
# 2     17.042651
# 3     17.382836
# 4     21.584432
# 5     22.392813
# 6     23.108841
# 7     24.034321
# 8     28.510000
# 9     29.192222
# 10    29.211290
# 11    31.019143
# 12    34.667403
# 13    35.586333
# 14    36.744400
# 15    37.979661
# 16    41.950690
# 17    42.667333
# 18    42.394935
# 19    43.845968
# 20    47.300704
# Name: Salary_LPA, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.scatter(df["Age"], df["Salary_LPA"], color="black")

plt.title = ("Age vs Salary_LPA")
plt.xlabel = ("Age")
plt.ylabel = ("Salary_LPA")
plt.grid(True)

plt.show()

# %%
edu = df["Education_Level"].value_counts()

plt.figure(figsize=(6,6))
plt.pie(edu,
        labels=edu.index,
        autopct="%1.1f%%",
        startangle=90)

plt.title = ("Education Distribution")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("First 5 Rows:")
print(df.head())
print("\nLast 5 Rows:")
print(df.tail())
print("\nDataset Information:")
print(df.info())
print("\nStatistical Summary:")
print(df.describe())
print("\nShape of Dataset:")
print(df.shape)
df.hist(figsize=(12,6))
plt.title = ("Feature Distributions")
plt.show()
# Out:
# First 5 Rows:
#    Employee_Id  Age  Experience Education_Level  Job_Level Department  \
# 0            1   30           6        Bachelor          2         HR
# 1            2   40          19        Bachelor          5  Marketing
# 2            3   39          14             PhD          4    Finance
# 3            4   38          10          Master          4         IT
# 4            5   34           7        Bachelor          3         IT
#
#    Performance_Score  Weekly_Working_Hours  Salary_LPA  Salary_updated
# 0                  3                  43.1       18.71           18.71
# 1                  8                  40.8       42.69           42.69
# 2                  2                  44.8       39.37           39.37
# 3                  4                  37.1       33.53           33.53
# 4                  3                  48.5       25.56           25.56
#
# Last 5 Rows:
#       Employee_Id  Age  Experience Education_Level  Job_Level  Department  \
# 1494         1495   36          16             PhD          5  Operations
# 1495         1496   26           7        Bachelor          3          HR
# 1496         1497   28           1        Bachelor          1          HR
# 1497         1498   33          12        Bachelor          4     Finance
# 1498         1499   21           2          Master          2  Operations
#
#       Performance_Score  Weekly_Working_Hours  Salary_LPA  Salary_updated
# 1494                  8                  45.9       46.01           46.01
# 1495                 10                  40.9       23.54           23.54
# 1496                  4                  50.2       13.49           13.49
# 1497                  2                  40.6       30.35           30.35
# 1498                  2                  42.4       16.76           16.76
#
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee_Id           1499 non-null   int64
#  1   Age                   1499 non-null   int64
#  2   Experience            1499 non-null   int64
#  3   Education_Level       1499 non-null   str
#  4   Job_Level             1499 non-null   int64
#  5   Department            1499 non-null   str
#  6   Performance_Score     1499 non-null   int64
#  7   Weekly_Working_Hours  1499 non-null   float64
#  8   Salary_LPA            1499 non-null   float64
#  9   Salary_updated        1499 non-null   float64
# dtypes: float64(3), int64(5), str(2)
# memory usage: 134.5 KB
# None
#
# Statistical Summary:
#        Employee_Id          Age   Experience    Job_Level  Performance_Score  \
# count   1499.00000  1499.000000  1499.000000  1499.000000        1499.000000
# mean     750.00000    33.198799     9.739827     3.328219           5.494330
# std      432.86834     6.549124     6.151434     1.569170           2.903511
# min        1.00000    21.000000     0.000000     1.000000           1.000000
# 25%      375.50000    28.000000     4.000000     2.000000           3.000000
# 50%      750.00000    33.000000    10.000000     3.000000           6.000000
# 75%     1124.50000    38.000000    15.000000     5.000000           8.000000
# max     1499.00000    48.000000    20.000000     6.000000          10.000000
#
#        Weekly_Working_Hours   Salary_LPA  Salary_updated
# count           1499.000000  1499.000000     1499.000000
# mean              41.844029    29.993155       29.993155
# std                4.028234    10.720923       10.720923
# min               32.000000     5.290000        5.290000
# 25%               39.200000    21.055000       21.055000
# 50%               41.800000    29.730000       29.730000
# 75%               44.500000    39.105000       39.105000
# max               55.000000    55.180000       55.180000
#
# Shape of Dataset:
# (1499, 10)
